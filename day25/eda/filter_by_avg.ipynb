# %%
import pandas as pd

# %% [markdown]
# ### Create a DataFrame

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Score': [85, 70, 90, 60, 95]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Score
# 0    Alice     85
# 1      Bob     70
# 2  Charlie     90
# 3    David     60
# 4      Eva     95

# %% [markdown]
# ### Calculate the average score

# %%
average_score = df['Score'].mean()
print("Average Score:", average_score)
# Out:
# Average Score: 80.0

# %% [markdown]
# ### Filter rows where Score is greater than the average

# %%
filtered_df = df[df['Score'] > average_score]

# %%
print()
print("Rows with Score greater than average:")
print(filtered_df)
# Out:
# Rows with Score greater than average:
#       Name  Score
# 0    Alice     85
# 2  Charlie     90
# 4      Eva     95
